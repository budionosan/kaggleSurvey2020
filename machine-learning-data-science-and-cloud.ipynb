# %% [markdown]
# Hello all, I am Budi. I write notebook about 2020 Kaggle Survey. From many questions are available, I choose 17 questions that related with machine learning, data science and cloud computing.
#
# Machine learning is a sub-field of artificial intelligence. However, in recent years, some organizations have begun using the terms artificial intelligence and machine learning interchangeably (https://developers.google.com/machine-learning/glossary#artificial-intelligence).
#
# Data science (data scientist) is the sexiest job of the 21st century (https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century).
#
# Cloud computing is the on-demand skill with pay cloud services that you use (not need data center or server), connected with internet or need internet to use/access cloud services (AWS, GCP and Azure website source).
#
# Machine learning, data science and cloud computing is each related. Amazon Sagemaker (AWS), AI Platform (GCP) and Azure ML Studio (Azure) is a machine learning product on the cloud services.
#
# Amazon Redshift (AWS), Amazon Athena (AWS), Google BigQuery (GCP), Cloud SQL (GCP), and Azure Data Lake (Azure) is a  data science (and data analytics) product on the cloud services.
#
# **If you interested with this notebook, read the results in this notebooks about 18 questions in Kaggle Survey 2020.**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv
# /kaggle/input/kaggle-survey-2020/supplementary_data/kaggle_survey_2020_methodology.pdf
# /kaggle/input/kaggle-survey-2020/supplementary_data/kaggle_survey_2020_answer_choices.pdf

# %%
# !pip install --upgrade plotly
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (4.14.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f4894291890>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/plotly/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f4894291d10>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/plotly/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f489425f110>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/plotly/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f489425f4d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/plotly/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f489425f890>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/plotly/
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from plotly) (1.14.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from plotly) (1.14.0)

# %%
data = pd.read_csv('../input/kaggle-survey-2020/kaggle_survey_2020_responses.csv')
data = data.drop(columns = ['Time from Start to Finish (seconds)'])
data = data.drop([0])
data
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           Q1     Q2                                                 Q3  \
# 1      35-39    Man                                           Colombia
# 2      30-34    Man                           United States of America
# 3      35-39    Man                                          Argentina
# 4      30-34    Man                           United States of America
# 5      30-34    Man                                              Japan
# ...      ...    ...                                                ...
# 20032  18-21    Man                                             Turkey
# 20033  55-59  Woman  United Kingdom of Great Britain and Northern I...
# 20034  30-34    Man                                             Brazil
# 20035  22-24    Man                                              India
# 20036  22-24    Man                                           Pakistan
#
#                                                       Q4  \
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# 5                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                               Q5           Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 1                        Student   5-10 years    Python         R       SQL
# 2                  Data Engineer   5-10 years    Python         R       SQL
# 3              Software Engineer  10-20 years       NaN       NaN       NaN
# 4                 Data Scientist   5-10 years    Python       NaN       SQL
# 5              Software Engineer    3-5 years    Python       NaN       NaN
# ...                          ...          ...       ...       ...       ...
# 20032                        NaN          NaN       NaN       NaN       NaN
# 20033     Currently not employed    20+ years    Python       NaN       NaN
# 20034         Research Scientist    < 1 years    Python       NaN       NaN
# 20035          Software Engineer    3-5 years    Python       NaN       SQL
# 20036  Machine Learning Engineer    < 1 years    Python       NaN       NaN
#
#       Q7_Part_4  ...        Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4  \
# 1             C  ...                 NaN          NaN          NaN
# 2           NaN  ...                 NaN          NaN          NaN
# 3           NaN  ...                 NaN          NaN          NaN
# 4           NaN  ...                 NaN          NaN          NaN
# 5           NaN  ...                 NaN          NaN          NaN
# ...         ...  ...                 ...          ...          ...
# 20032       NaN  ...                 NaN          NaN          NaN
# 20033       NaN  ...                 NaN          NaN          NaN
# 20034       NaN  ...                 NaN          NaN          NaN
# 20035         C  ...   Weights & Biases           NaN          NaN
# 20036       NaN  ...   Weights & Biases           NaN          NaN
#
#         Q35_B_Part_5 Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9  \
# 1       TensorBoard           NaN          NaN          NaN          NaN
# 2                NaN          NaN          NaN          NaN          NaN
# 3                NaN          NaN          NaN          NaN          NaN
# 4                NaN          NaN          NaN          NaN          NaN
# 5                NaN          NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...          ...
# 20032            NaN          NaN          NaN          NaN          NaN
# 20033            NaN          NaN          NaN          NaN          NaN
# 20034            NaN          NaN          NaN          NaN          NaN
# 20035   TensorBoard           NaN          NaN      Trains           NaN
# 20036            NaN          NaN          NaN      Trains           NaN
#
#       Q35_B_Part_10 Q35_B_OTHER
# 1               NaN         NaN
# 2               NaN         NaN
# 3              None         NaN
# 4               NaN         NaN
# 5               NaN         NaN
# ...             ...         ...
# 20032           NaN         NaN
# 20033          None         NaN
# 20034           NaN         NaN
# 20035           NaN         NaN
# 20036           NaN         NaN
#
# [20036 rows x 354 columns]

# %% [markdown]
# In this survey, 2020 Kaggle Survey have more than 20000 participant. I use Seaborn and Plotly library for analysis 18 questions in this notebook.
#
# **Question one ("Q1")** about age participant. 25-29 years old are the largest number of age participant. Followed, 22-24 years old, 18-21 years old. In means, total participant from top three age (18-21, 22-24 and 25-29 or 18-29) more than 50%. After 18-29 years of age or over 29 years of age, there are fewer participants.

# %%
plt.figure(figsize=(15, 5))
plt.xticks(size=20)

q1 = sns.countplot(x=data['Q1'], data=data)
q1

for p in q1.patches:
  height = p.get_height()
  q1.text(p.get_x()+p.get_width()/2., height, height , ha="center")
  
plt.title('Age Participant of Kaggle Survey 2020', fontsize=20)
plt.show()

# %% [markdown]
# **Question two ("Q2")** about gender participant. 78.8% of the total participants are man. While 21.2% are woman and other.
#
# Now, machine learning and data science world has community that focused for woman and other/underrepresented groups (African Americans/Black, Hispanic/Latin, Asian, Disability, LGBTQ+ and many more)(https://blog.ongig.com/diversity-and-inclusion/minority-groups-in-america/)

# %%
q2 = data['Q2'].value_counts()
fig = px.pie(names=q2.index, values=q2.values)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="25bb2508-9202-440d-a3ae-6c9e996e14ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25bb2508-9202-440d-a3ae-6c9e996e14ff")) {                    Plotly.newPlot(                        "25bb2508-9202-440d-a3ae-6c9e996e14ff",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["Man", "Woman", "Prefer not to say", "Prefer to self-describe", "Nonbinary"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [15789, 3878, 263, 54, 52]}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatt ...

# %% [markdown]
# **Question three ("Q3")** about country participant. In this question, I choose top 9 country excluded "Other". India is the country that has participated the most in the 2020 Kaggle Survey.
#
# Followed, United States, then Brazil, Japan, Russia, United Kingdom, Nigeria, China and Germany. Machine learning and data science resources are mostly written in English.
#
# India, United States and United Kingdom are country is communicate in English (https://www.lingoda.com/en/content/english-speaking-countries/). India total participant are two times United States total participant in this question.

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q3 = sns.countplot(y=data['Q3'], data=data, order=data['Q3'].value_counts().iloc[:10].index)
q3

plt.title('Country Participant of Kaggle Survey 2020', fontsize=20)
plt.show()

data['Q3'].value_counts()[:10]
# Out:
# India                                                   5851
# United States of America                                2237
# Other                                                   1388
# Brazil                                                   694
# Japan                                                    638
# Russia                                                   582
# United Kingdom of Great Britain and Northern Ireland     489
# Nigeria                                                  476
# China                                                    474
# Germany                                                  404
# Name: Q3, dtype: int64

# %% [markdown]
# **Question ten ("Q10")** about notebooks used by participant. In this question, I create treemap visualization because many notebooks product like Colab Notebooks, Kaggle Notebooks and many more. Btw, I use Colab and Kaggle Notebooks because it's free with GPU limited hours.
#
# Kaggle Notebooks, a cloud computational environment that enables reproducible and collaborative analysis (https://www.kaggle.com/docs/notebooks). While Colaboratory execute code on Google's cloud servers, including GPUs and TPUs and need is a browser (https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=OwuxHmxllTwN).
#
# Notebooks hosted on cloud services like Amazon Sagemaker, Google Cloud Datalab, Google Cloud AI Platform and Azure Notebooks has pricing model with other cloud services.
# It is proven that there are still many people who do not use notebooks (None) as many as 25% of the more than 20,000 participants.

# %%
notebooks = [data['Q10_Part_1'].any(), data['Q10_Part_2'].any(), data['Q10_Part_3'].any(), data['Q10_Part_4'].any(),
             data['Q10_Part_5'].any(), data['Q10_Part_6'].any(), data['Q10_Part_7'].any(), data['Q10_Part_8'].any(),
             data['Q10_Part_9'].any(), data['Q10_Part_10'].any(), data['Q10_Part_11'].any(), data['Q10_Part_12'].any(),
             data['Q10_Part_13'].any(), data['Q10_OTHER'].any()]

totals = [data['Q10_Part_1'].value_counts().tolist()[0], data['Q10_Part_2'].value_counts().tolist()[0],
          data['Q10_Part_3'].value_counts().tolist()[0], data['Q10_Part_4'].value_counts().tolist()[0],
          data['Q10_Part_5'].value_counts().tolist()[0], data['Q10_Part_6'].value_counts().tolist()[0],
          data['Q10_Part_7'].value_counts().tolist()[0], data['Q10_Part_8'].value_counts().tolist()[0],
          data['Q10_Part_9'].value_counts().tolist()[0], data['Q10_Part_10'].value_counts().tolist()[0],
          data['Q10_Part_11'].value_counts().tolist()[0], data['Q10_Part_12'].value_counts().tolist()[0],
          data['Q10_Part_13'].value_counts().tolist()[0], data['Q10_OTHER'].value_counts().tolist()[0]]

df = pd.DataFrame(
    dict(notebooks=notebooks, totals=totals)
)

fig = px.treemap(df, path=['notebooks'], values='totals', width=1000, height=1000)
fig.show()
# Out:
# <div>                            <div id="64887e70-867e-49be-8e08-8d71415c52d9" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64887e70-867e-49be-8e08-8d71415c52d9")) {                    Plotly.newPlot(                        "64887e70-867e-49be-8e08-8d71415c52d9",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>totals=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": [" Amazon EMR Notebooks ", " Amazon Sagemaker Studio ", " Binder / JupyterHub ", " Code Ocean ", " Databricks Collaborative Notebooks ", " IBM Watson Studio ", " Kaggle Notebooks", " Paperspace / Gradient ", "Azure Notebooks", "Colab Notebooks", "Google Cloud AI Platform Notebooks ", "Google Cloud Datalab Notebooks", "None", "Other"], "labels": [" Amazon EMR Notebooks ", " Amazon Sagemaker Studio ", " Binder / JupyterHub ", " Code Ocean ", " Databricks Collaborative Notebooks ", " IBM Watson Studio ", " Kaggle Notebooks", " Paperspace / Gradient ", "Azure Notebooks", "Colab Notebooks", "Google Cloud AI Platform Notebooks ", "Google Cloud Datalab Notebooks", "None", "Other"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [245, 497, 2072, 105, 394, 846, 5992, 180, 857, 6329, 1218, 1231, 5282, 485]}],                        {"height": 1000, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666,  ...

# %% [markdown]
# **Question evelen ("Q11")** about computing platform used by participant. Majority still many use personal computer or laptop. Followed, cloud provider like AWS, Azure, GCP, hosted notebooks (Kaggle Notebooks, Colab Notebooks and many more (you can see on question 10)).

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q11 = sns.countplot(y=data['Q11'], data=data)
q11

plt.title('Computing Platform of Kaggle Survey 2020', fontsize=20)
plt.show()

data['Q11'].value_counts()
# Out:
# A personal computer or laptop                                          13348
# A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)     2358
# A deep learning workstation (NVIDIA GTX, LambdaLabs, etc)                834
# None                                                                     292
# Other                                                                    197
# Name: Q11, dtype: int64

# %% [markdown]
# **Question twelve ("Q12")** about hardware used by participant. Majority of people still use GPUs and don't use hardware. TPU is still rarely used.

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q12 = {'1': [data['Q12_Part_1'].any(), data['Q12_Part_2'].any(), data['Q12_Part_3'].any(), data['Q12_OTHER'].any()],
       '2': [data['Q12_Part_1'].value_counts().tolist()[0], data['Q12_Part_2'].value_counts().tolist()[0],
             data['Q12_Part_3'].value_counts().tolist()[0], data['Q12_OTHER'].value_counts().tolist()[0]]}
             
sns.barplot(x=q12['1'], y=q12['2'])

plt.title('Hardware of Kaggle Survey 2020', fontsize=16)
plt.show()

print(data['Q12_Part_1'].any(), data['Q12_Part_1'].value_counts().tolist()[0])
print(data['Q12_Part_2'].any(), data['Q12_Part_2'].value_counts().tolist()[0])
print(data['Q12_Part_3'].any(), data['Q12_Part_3'].value_counts().tolist()[0])
print(data['Q12_OTHER'].any(), data['Q12_OTHER'].value_counts().tolist()[0])
# Out:
# GPUs 8310
# TPUs 960
# None 7891
# Other 666

# %% [markdown]
# **Question thirteen ("Q13")** about TPU hours used by participant. Majority of people still not use TPUs. You can see question twelve (Q12) explained people that use TPUs rarely used.

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q13 = sns.countplot(x=data['Q13'], data=data)
q13

plt.title('TPU used of hours | Kaggle Survey 2020', fontsize=20)
plt.show()


print(data['Q12_Part_1'].any(), data['Q12_Part_1'].value_counts().tolist()[0])
print(data['Q12_Part_2'].any(), data['Q12_Part_2'].value_counts().tolist()[0])
print(data['Q12_Part_3'].any(), data['Q12_Part_3'].value_counts().tolist()[0])
print(data['Q12_OTHER'].any(), data['Q12_OTHER'].value_counts().tolist()[0])
# Out:
# GPUs 8310
# TPUs 960
# None 7891
# Other 666

# %% [markdown]
# **Question fourteen ("Q14")** about data visualization library used by participant. Top three are matplotlib, seaborn and Plotly. I use seaborn and Plotly in this notebooks.

# %%
visual = [data['Q14_Part_1'].any(), data['Q14_Part_2'].any(), data['Q14_Part_3'].any(), data['Q14_Part_4'].any(),
             data['Q14_Part_5'].any(), data['Q14_Part_6'].any(), data['Q14_Part_7'].any(), data['Q14_Part_8'].any(),
             data['Q14_Part_9'].any(), data['Q14_Part_10'].any(), data['Q14_Part_11'].any(), data['Q14_OTHER'].any()]

totals = [data['Q14_Part_1'].value_counts().tolist()[0], data['Q14_Part_2'].value_counts().tolist()[0],
          data['Q14_Part_3'].value_counts().tolist()[0], data['Q14_Part_4'].value_counts().tolist()[0],
          data['Q14_Part_5'].value_counts().tolist()[0], data['Q14_Part_6'].value_counts().tolist()[0],
          data['Q14_Part_7'].value_counts().tolist()[0], data['Q14_Part_8'].value_counts().tolist()[0],
          data['Q14_Part_9'].value_counts().tolist()[0], data['Q14_Part_10'].value_counts().tolist()[0],
          data['Q14_Part_11'].value_counts().tolist()[0], data['Q14_OTHER'].value_counts().tolist()[0]]

df = pd.DataFrame(
    dict(visual=visual, totals=totals)
)

fig = px.treemap(df, path=['visual'], values='totals', width=1000, height=1000)
fig.show()
# Out:
# <div>                            <div id="cab764a9-fdf1-4db3-bc92-6f51b9ea9fa9" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cab764a9-fdf1-4db3-bc92-6f51b9ea9fa9")) {                    Plotly.newPlot(                        "cab764a9-fdf1-4db3-bc92-6f51b9ea9fa9",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>totals=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": [" Altair ", " Bokeh ", " D3 js ", " Geoplotlib ", " Ggplot / ggplot2 ", " Leaflet / Folium ", " Matplotlib ", " Plotly / Plotly Express ", " Seaborn ", " Shiny ", "None", "Other"], "labels": [" Altair ", " Bokeh ", " D3 js ", " Geoplotlib ", " Ggplot / ggplot2 ", " Leaflet / Folium ", " Matplotlib ", " Plotly / Plotly Express ", " Seaborn ", " Shiny ", "None", "Other"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [233, 920, 829, 850, 4120, 596, 12342, 4130, 8821, 1137, 1897, 565]}],                        {"height": 1000, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0. ...

# %% [markdown]
# **Question sixteen ("Q16")** about machine learning framework used by participant. Top four are Scikit-learn, TensorFlow, Keras, and PyTorch. TensorFlow and Keras has integrated to be TensorFlow only (https://twitter.com/fchollet/status/820746845068505088).
#
# I look at the growth in use of PyTorch and TensorFlow libraries. We can see that PyTorch is growing faster than TensorFlow, but TensorFlow are first machine learning framework most used.
# In 2020, in Jetbrains Blog, TensorFlow used 420K people and PyTorch 253K people. You can see on https://blog.jetbrains.com/datalore/2020/12/17/we-downloaded-10-000-000-jupyter-notebooks-from-github-this-is-what-we-learned/ .

# %%
library = [data['Q16_Part_1'].any(), data['Q16_Part_2'].any(), data['Q16_Part_3'].any(), data['Q16_Part_4'].any(),
             data['Q16_Part_5'].any(), data['Q16_Part_6'].any(), data['Q16_Part_7'].any(), data['Q16_Part_8'].any(),
             data['Q16_Part_9'].any(), data['Q16_Part_10'].any(), data['Q16_Part_11'].any(), data['Q16_Part_12'].any(),
             data['Q16_Part_13'].any(), data['Q16_Part_14'].any(), data['Q16_Part_15'].any(), data['Q16_OTHER'].any()]

totals = [data['Q16_Part_1'].value_counts().tolist()[0], data['Q16_Part_2'].value_counts().tolist()[0],
          data['Q16_Part_3'].value_counts().tolist()[0], data['Q16_Part_4'].value_counts().tolist()[0],
          data['Q16_Part_5'].value_counts().tolist()[0], data['Q16_Part_6'].value_counts().tolist()[0],
          data['Q16_Part_7'].value_counts().tolist()[0], data['Q16_Part_8'].value_counts().tolist()[0],
          data['Q16_Part_9'].value_counts().tolist()[0], data['Q16_Part_10'].value_counts().tolist()[0],
          data['Q16_Part_11'].value_counts().tolist()[0], data['Q16_Part_12'].value_counts().tolist()[0],
          data['Q16_Part_13'].value_counts().tolist()[0], data['Q16_Part_14'].value_counts().tolist()[0],
          data['Q16_Part_15'].value_counts().tolist()[0], data['Q16_OTHER'].value_counts().tolist()[0]]

df = pd.DataFrame(
    dict(library=library, totals=totals)
)

fig = px.treemap(df, path=['library'], values='totals', width=1000, height=1000)
fig.show()
# Out:
# <div>                            <div id="346ba282-b03c-4ec0-9e60-c251ca24ac55" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("346ba282-b03c-4ec0-9e60-c251ca24ac55")) {                    Plotly.newPlot(                        "346ba282-b03c-4ec0-9e60-c251ca24ac55",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>totals=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["  Scikit-learn ", "  TensorFlow ", " Caret ", " CatBoost ", " Fast.ai ", " H2O 3 ", " JAX ", " Keras ", " LightGBM ", " MXNet ", " Prophet ", " PyTorch ", " Tidymodels ", " Xgboost ", "None", "Other"], "labels": ["  Scikit-learn ", "  TensorFlow ", " Caret ", " CatBoost ", " Fast.ai ", " H2O 3 ", " JAX ", " Keras ", " LightGBM ", " MXNet ", " Prophet ", " PyTorch ", " Tidymodels ", " Xgboost ", "None", "Other"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [10250, 6934, 939, 957, 742, 344, 84, 6192, 1799, 218, 532, 4189, 484, 3935, 1208, 371]}],                        {"height": 1000, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, " ...

# %% [markdown]
# **Question seventeen ("Q17")** about machine learning algorithm used by participant. Top three are linear regression, decision tree or random forest, and convolutional neural network (CNN).

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q17 = {'1': [data['Q17_Part_1'].any(), data['Q17_Part_2'].any(), data['Q17_Part_3'].any(), data['Q17_Part_4'].any(),
             data['Q17_Part_5'].any(), data['Q17_Part_6'].any(), data['Q17_Part_7'].any(), data['Q17_Part_8'].any(),
             data['Q17_Part_9'].any(), data['Q17_Part_10'].any(), data['Q17_Part_11'].any(), data['Q17_OTHER'].any()],
       '2': [data['Q17_Part_1'].value_counts().tolist()[0], data['Q17_Part_2'].value_counts().tolist()[0],
             data['Q17_Part_3'].value_counts().tolist()[0], data['Q17_Part_4'].value_counts().tolist()[0],
             data['Q17_Part_5'].value_counts().tolist()[0], data['Q17_Part_6'].value_counts().tolist()[0],
             data['Q17_Part_7'].value_counts().tolist()[0], data['Q17_Part_8'].value_counts().tolist()[0],
             data['Q17_Part_9'].value_counts().tolist()[0], data['Q17_Part_10'].value_counts().tolist()[0],
             data['Q17_Part_11'].value_counts().tolist()[0], data['Q17_OTHER'].value_counts().tolist()[0]]}
  
sns.barplot(y=q17['1'], x=q17['2'])

plt.title('ML Algorithm of Kaggle Survey 2020', fontsize=20)
plt.show()

# %% [markdown]
# **Question eighteen ("Q18")** about computer vision methods used by participant. Image classification are computer vision methods that most used. Image classification is a process that classifies object(s), pattern(s), or concept(s) in an image (https://developers.google.com/machine-learning/glossary#image-recognition).

# %%
labels = [data['Q18_Part_1'].any(), data['Q18_Part_2'].any(), data['Q18_Part_3'].any(), data['Q18_Part_4'].any(),
             data['Q18_Part_5'].any(), data['Q18_Part_6'].any(), data['Q18_OTHER'].any()]

values = [data['Q18_Part_1'].value_counts().tolist()[0], data['Q18_Part_2'].value_counts().tolist()[0],
          data['Q18_Part_3'].value_counts().tolist()[0], data['Q18_Part_4'].value_counts().tolist()[0],
          data['Q18_Part_5'].value_counts().tolist()[0], data['Q18_Part_6'].value_counts().tolist()[0],
          data['Q18_OTHER'].value_counts().tolist()[0]]

df = pd.DataFrame(
    dict(labels=labels, values=values)
)

fig = px.treemap(df, path=['labels'], values='values', width=1000, height=1000)
fig.show()
# Out:
# <div>                            <div id="77d76a2a-5e14-456f-bd28-04ac1c0da72c" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77d76a2a-5e14-456f-bd28-04ac1c0da72c")) {                    Plotly.newPlot(                        "77d76a2a-5e14-456f-bd28-04ac1c0da72c",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>value=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["General purpose image/video tools (PIL, cv2, skimage, etc)", "Generative Networks (GAN, VAE, etc)", "Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc)", "Image segmentation methods (U-Net, Mask R-CNN, etc)", "None", "Object detection methods (YOLOv3, RetinaNet, etc)", "Other"], "labels": ["General purpose image/video tools (PIL, cv2, skimage, etc)", "Generative Networks (GAN, VAE, etc)", "Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc)", "Image segmentation methods (U-Net, Mask R-CNN, etc)", "None", "Object detection methods (YOLOv3, RetinaNet, etc)", "Other"], "name": "", "parents": ["", "", "", "", "", "", ""], "type": "treemap", "values": [2139, 1092, 3512, 2003, 1153, 2079, 71]}],                        {"height": 1000, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"] ...

# %% [markdown]
# **Question nineteen ("Q19")** about NLP methods used by participant. Word embedding are NLP methods that most used.

# %%
labels = [data['Q19_Part_1'].any(), data['Q19_Part_2'].any(), data['Q19_Part_3'].any(), data['Q19_Part_4'].any(),
             data['Q19_Part_5'].any(),  data['Q19_OTHER'].any()]

values = [data['Q19_Part_1'].value_counts().tolist()[0], data['Q19_Part_2'].value_counts().tolist()[0],
          data['Q19_Part_3'].value_counts().tolist()[0], data['Q19_Part_4'].value_counts().tolist()[0],
          data['Q19_Part_5'].value_counts().tolist()[0], data['Q19_OTHER'].value_counts().tolist()[0]]

fix = go.Figure(data=[go.Pie(labels=labels, values=values)])
fix.show()
# Out:
# <div>                            <div id="6614f4dc-c5a1-4271-a39d-b538a2c9e596" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6614f4dc-c5a1-4271-a39d-b538a2c9e596")) {                    Plotly.newPlot(                        "6614f4dc-c5a1-4271-a39d-b538a2c9e596",                        [{"labels": ["Word embeddings/vectors (GLoVe, fastText, word2vec)", "Encoder-decorder models (seq2seq, vanilla transformers)", "Contextualized embeddings (ELMo, CoVe)", "Transformer language models (GPT-3, BERT, XLnet, etc)", "None", "Other"], "type": "pie", "values": [2110, 1514, 557, 1428, 1047, 82]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ...

# %% [markdown]
# **Question twenty six ("Q26")** about cloud computing platform. In this question, AWS and GCP are top two cloud computing platform. While in Flexera blog, AWS are cloud computing platform that most used, followed Azure and GCP (https://www.flexera.com/blog/industry-trends/trend-of-cloud-computing-2020/). Various survey also explain top three cloud computing always are AWS, GCP and Azure. AWS, GCP and Azure have several services in common like compute, networking, storage, database and many more.

# %%
cloud = [data['Q26_A_Part_1'].any(), data['Q26_A_Part_2'].any(), data['Q26_A_Part_3'].any(), data['Q26_A_Part_4'].any(),
             data['Q26_A_Part_5'].any(), data['Q26_A_Part_6'].any(), data['Q26_A_Part_7'].any(), data['Q26_A_Part_8'].any(),
             data['Q26_A_Part_9'].any(), data['Q26_A_Part_10'].any(), data['Q26_A_Part_11'].any(), data['Q26_A_OTHER'].any()]

totals = [data['Q26_A_Part_1'].value_counts().tolist()[0], data['Q26_A_Part_2'].value_counts().tolist()[0],
          data['Q26_A_Part_3'].value_counts().tolist()[0], data['Q26_A_Part_4'].value_counts().tolist()[0],
          data['Q26_A_Part_5'].value_counts().tolist()[0], data['Q26_A_Part_6'].value_counts().tolist()[0],
          data['Q26_A_Part_7'].value_counts().tolist()[0], data['Q26_A_Part_8'].value_counts().tolist()[0],
          data['Q26_A_Part_9'].value_counts().tolist()[0], data['Q26_A_Part_10'].value_counts().tolist()[0],
          data['Q26_A_Part_11'].value_counts().tolist()[0], data['Q26_A_OTHER'].value_counts().tolist()[0]]

df = pd.DataFrame(
    dict(cloud=cloud, totals=totals)
)

fig = px.treemap(df, path=['cloud'], values='totals', width=1000, height=1000)
fig.show()
# Out:
# <div>                            <div id="af2aac6f-e031-4d5f-8e19-cf6cacc34f10" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af2aac6f-e031-4d5f-8e19-cf6cacc34f10")) {                    Plotly.newPlot(                        "af2aac6f-e031-4d5f-8e19-cf6cacc34f10",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>totals=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": [" Alibaba Cloud ", " Amazon Web Services (AWS) ", " Google Cloud Platform (GCP) ", " IBM Cloud / Red Hat ", " Microsoft Azure ", " Oracle Cloud ", " SAP Cloud ", " Salesforce Cloud ", " Tencent Cloud ", " VMware Cloud ", "None", "Other"], "labels": [" Alibaba Cloud ", " Amazon Web Services (AWS) ", " Google Cloud Platform (GCP) ", " IBM Cloud / Red Hat ", " Microsoft Azure ", " Oracle Cloud ", " SAP Cloud ", " Salesforce Cloud ", " Tencent Cloud ", " VMware Cloud ", "None", "Other"], "name": "", "parents": ["", "", "", "", "", "", "", "", "", "", "", ""], "type": "treemap", "values": [115, 2806, 2286, 441, 1705, 286, 169, 192, 76, 248, 1837, 245]}],                        {"height": 1000, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "# ...

# %% [markdown]
# **Question twenty seven ("Q27")** about cloud computing products. This question has three cloud computing platform (AWS, GCP and Azure) answer. If seen total participant use cloud computing products, AWS are first answer for this question followed GCP and Azure.
#
# AWS services that most use are Amazon EC2, then AWS Lambda and Amazon Elastic Container Service. Then, still many people not use cloud computing platform (No/None). No/None are ranking two after Amazon EC2.

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q27 = {'1': [data['Q27_A_Part_1'].any(), data['Q27_A_Part_2'].any(), data['Q27_A_Part_3'].any(), data['Q27_A_Part_4'].any(),
             data['Q27_A_Part_5'].any(), data['Q27_A_Part_6'].any(), data['Q27_A_Part_7'].any(), data['Q27_A_Part_8'].any(),
             data['Q27_A_Part_9'].any(), data['Q27_A_Part_10'].any(), data['Q27_A_Part_11'].any(), data['Q27_A_OTHER'].any()],
       '2': [data['Q27_A_Part_1'].value_counts().tolist()[0], data['Q27_A_Part_2'].value_counts().tolist()[0],
             data['Q27_A_Part_3'].value_counts().tolist()[0], data['Q27_A_Part_4'].value_counts().tolist()[0],
             data['Q27_A_Part_5'].value_counts().tolist()[0], data['Q27_A_Part_6'].value_counts().tolist()[0],
             data['Q27_A_Part_7'].value_counts().tolist()[0], data['Q27_A_Part_8'].value_counts().tolist()[0],
             data['Q27_A_Part_9'].value_counts().tolist()[0], data['Q27_A_Part_10'].value_counts().tolist()[0],
             data['Q27_A_Part_11'].value_counts().tolist()[0], data['Q27_A_OTHER'].value_counts().tolist()[0]]}
             
cloudProducts = sns.barplot(y=q27['1'], x=q27['2'])
cloudProducts.tick_params(labelsize=12)
cloudProducts.tick_params(length=2, axis='y')
plt.tight_layout()
plt.title('Cloud Products of Kaggle Survey 2020', fontsize=20)
plt.show()

# %% [markdown]
# **Question twenty eight ("Q28")** about machine learning products. This question has three cloud computing platform (AWS, GCP and Azure) answer. Still many people not use machine learning products on cloud. No/None are ranking 1 for this question. While machine learning products by GCP are Google Cloud AI Platform is ranking 2, followed by AWS are Amazon Sagemaker is ranking 3, by Azure are Azure ML Studio is ranking 4.

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q28 = {'1': [data['Q28_A_Part_1'].any(), data['Q28_A_Part_2'].any(), data['Q28_A_Part_3'].any(), data['Q28_A_Part_4'].any(),
             data['Q28_A_Part_5'].any(), data['Q28_A_Part_6'].any(), data['Q28_A_Part_7'].any(), data['Q28_A_Part_8'].any(),
             data['Q28_A_Part_9'].any(), data['Q28_A_Part_10'].any(), data['Q28_A_OTHER'].any()],
       '2': [data['Q28_A_Part_1'].value_counts().tolist()[0], data['Q28_A_Part_2'].value_counts().tolist()[0],
             data['Q28_A_Part_3'].value_counts().tolist()[0], data['Q28_A_Part_4'].value_counts().tolist()[0],
             data['Q28_A_Part_5'].value_counts().tolist()[0], data['Q28_A_Part_6'].value_counts().tolist()[0],
             data['Q28_A_Part_7'].value_counts().tolist()[0], data['Q28_A_Part_8'].value_counts().tolist()[0],
             data['Q28_A_Part_9'].value_counts().tolist()[0], data['Q28_A_Part_10'].value_counts().tolist()[0],
             data['Q28_A_OTHER'].value_counts().tolist()[0]]}
             
MLProducts = sns.barplot(y=q28['1'], x=q28['2']) 
MLProducts.tick_params(labelsize=12)
MLProducts.tick_params(length=2, axis='y')
plt.tight_layout()
plt.title('ML Products of Kaggle Survey 2020', fontsize=20)
plt.show()

# %% [markdown]
# **Question twenty nine ("Q29")** about big data products. In this question, I filtered several answers into cloud big data products only. As a result, BigQuery are first answer most used to big data products. Other cloud big data services have a nearly equal number of participants.

# %%
plt.figure(figsize=(15, 5))
plt.yticks(size=20)

q29 = {'1': [data['Q29_A_Part_10'].any(), data['Q29_A_Part_11'].any(), data['Q29_A_Part_12'].any(), data['Q29_A_Part_13'].any(),
         data['Q29_A_Part_14'].any(), data['Q29_A_Part_15'].any(), data['Q29_A_Part_16'].any()],
       '2': [data['Q29_A_Part_10'].value_counts().tolist()[0], data['Q29_A_Part_11'].value_counts().tolist()[0],
          data['Q29_A_Part_12'].value_counts().tolist()[0], data['Q29_A_Part_13'].value_counts().tolist()[0],
          data['Q29_A_Part_14'].value_counts().tolist()[0], data['Q29_A_Part_15'].value_counts().tolist()[0],
          data['Q29_A_Part_16'].value_counts().tolist()[0]]}

bigDataProducts = sns.barplot(y=q29['1'], x=q29['2']) 
bigDataProducts.tick_params(labelsize=12)
bigDataProducts.tick_params(length=2, axis='y')
plt.tight_layout()
plt.title('Big Data Products of Kaggle Survey 2020', fontsize=20)
plt.show()

# %% [markdown]
# **Question thirty ("Q30")** about business intelligence products. Tableau is business intelligence products that most used with 36% total participant of 2020 Kaggle Survey. Tableau has several products like Tableau Desktop, Tableau Server, Tableau Online and many more. Followed, Power BI by Microsoft are ranking two, Google Data Studio are ranking three.
#
# Tableau and Power BI has integrations services with Google BigQuery, Amazon Redshift and many more. Google Data Studio running in the browser, can integrated with Google BigQuery and many more. Amazon Quicksight has 2.4% total participant, is are cloud business intelligence products by AWS. While, Looker are acquisition by Google and Looker available on Google Cloud Platform (GCP).

# %%
q32 = data['Q32'].value_counts()
fig = px.pie(names=q32.index, values=q32.values)
fig.show()
# Out:
# <div>                            <div id="7a148581-8395-4278-8b75-4e6d8196928d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a148581-8395-4278-8b75-4e6d8196928d")) {                    Plotly.newPlot(                        "7a148581-8395-4278-8b75-4e6d8196928d",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["Tableau", "Microsoft Power BI", "Google Data Studio", "Qlik", "Other", "Salesforce", "Amazon QuickSight", "SAP Analytics Cloud ", "Alteryx ", "TIBCO Spotfire", "Looker", "Sisense ", "Einstein Analytics", "Domo"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [540, 462, 167, 69, 57, 51, 36, 31, 27, 22, 19, 6, 6, 5]}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""},  ...

# %% [markdown]
# Thank you for reading this notebooks. I done specify sources with drop link. Once again, thank you :)
